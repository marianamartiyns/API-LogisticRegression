# %% [markdown]
# # Classificação de Churn com Regressão Logística
# ```
# # O que é Churn?
# Churn é uma métrica que indica o quanto sua empresa perdeu de receita ou clientes.
# ```
#
# O dataset utilizado é proveniente de uma empresa fictícia de telefonia, criado e disponibilizado pela IBM para fins didáticos.
#
# O dicionário com as descrições das features pode ser encontrado [neste link no Kaggle](https://www.kaggle.com/datasets/yeanzc/telco-customer-churn-ibm-dataset).

# %% [markdown]
# # 🧩 Libraries

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm

from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, roc_auc_score

# %%
from sklearn import set_config
set_config(display='diagram')

# %% [markdown]
# # 🗂️ Data

# %%
df_mi = pd.read_csv('/content/churn_df.csv', index_col=0)
display(df_mi)
# Out:
#              Latitude   Longitude  Gender  Senior Citizen  Partner  \
# CustomerID
# 3668-QPYBK  33.964131 -118.272783       1               0        0
# 9237-HQITU  34.059281 -118.307420       0               0        0
# 9305-CDSKC  34.048013 -118.293953       0               0        0
# 7892-POOKP  34.062125 -118.315709       0               0        1
# 0280-XJGEX  34.039224 -118.266293       1               0        0
# ...               ...         ...     ...             ...      ...
# 2569-WGERO  34.341737 -116.539416       0               0        0
# 6840-RESVB  34.667815 -117.536183       1               0        1
# 2234-XADUH  34.559882 -115.637164       0               0        1
# 4801-JZAZL  34.167800 -116.864330       0               0        1
# 3186-AJIEK  34.424926 -117.184503       1               0        0
#
#             Dependents  Tenure Months  Phone Service  Multiple Lines  \
# CustomerID
# 3668-QPYBK           0              2              1               0
# 9237-HQITU           1              2              1               0
# 9305-CDSKC           1              8              1               2
# 7892-POOKP           1             28              1               2
# 0280-XJGEX           1             49              1               2
# ...                ...            ...            ...             ...
# 2569-WGERO           0             72              1               0
# 6840-RESVB           1             24              1               2
# 2234-XADUH           1             72              1               2
# 4801-JZAZL           1             11              0               1
# 3186-AJIEK           0             66              1               0
#
#             Internet Service  ...  Tech Support  Streaming TV  \
# CustomerID                    ...
# 3668-QPYBK                 0  ...             0             0
# 9237-HQITU                 1  ...             0             0
# 9305-CDSKC                 1  ...             0             2
# 7892-POOKP                 1  ...             2             2
# 0280-XJGEX                 1  ...             0             2
# ...                      ...  ...           ...           ...
# 2569-WGERO                 2  ...             1             1
# 6840-RESVB                 0  ...             2             2
# 2234-XADUH                 1  ...             0             2
# 4801-JZAZL                 0  ...             0             0
# 3186-AJIEK                 1  ...             2             2
#
#             Streaming Movies  Contract  Paperless Billing  Payment Method  \
# CustomerID
# 3668-QPYBK                 0         0                  1               3
# 9237-HQITU                 0         0                  1               2
# 9305-CDSKC                 2         0                  1               2
# 7892-POOKP                 2         0                  1               2
# 0280-XJGEX                 2         0                  1               0
# ...                      ...       ...                ...             ...
# 2569-WGERO                 1         2                  1               0
# 6840-RESVB                 2         1                  1               3
# 2234-XADUH                 2         1                  1               1
# 4801-JZAZL                 0         0                  1               2
# 3186-AJIEK                 2         2                  1               0
#
#             Monthly Charges  Total Charges  Churn Value  CLTV
# CustomerID
# 3668-QPYBK            53.85         108.15            1  3239
# 9237-HQITU            70.70         151.65            1  2701
# 9305-CDSKC            99.65         820.50            1  5372
# 7892-POOKP           104.80        3046.05            1  5003
# 0280-XJGEX           103.70        5036.30            1  5340
# ...                     ...            ...          ...   ...
# 2569-WGERO            21.15        1419.40            0  5306
# 6840-RESVB            84.80        1990.50            0  2140
# 2234-XADUH           103.20        7362.90            0  5560
# 4801-JZAZL            29.60         346.45            0  2793
# 3186-AJIEK           105.65        6844.50            0  5097
#
# [7043 rows x 23 columns]

# %% [markdown]
# # 🤖 Model Building

# %%
df_features = df_mi.drop(columns='Churn Value')
target = df_mi['Churn Value']

# %%
df_features.head()
# Out:
#              Latitude   Longitude  Gender  Senior Citizen  Partner  \
# CustomerID
# 3668-QPYBK  33.964131 -118.272783       1               0        0
# 9237-HQITU  34.059281 -118.307420       0               0        0
# 9305-CDSKC  34.048013 -118.293953       0               0        0
# 7892-POOKP  34.062125 -118.315709       0               0        1
# 0280-XJGEX  34.039224 -118.266293       1               0        0
#
#             Dependents  Tenure Months  Phone Service  Multiple Lines  \
# CustomerID
# 3668-QPYBK           0              2              1               0
# 9237-HQITU           1              2              1               0
# 9305-CDSKC           1              8              1               2
# 7892-POOKP           1             28              1               2
# 0280-XJGEX           1             49              1               2
#
#             Internet Service  ...  Device Protection  Tech Support  \
# CustomerID                    ...
# 3668-QPYBK                 0  ...                  0             0
# 9237-HQITU                 1  ...                  0             0
# 9305-CDSKC                 1  ...                  2             0
# 7892-POOKP                 1  ...                  2             2
# 0280-XJGEX                 1  ...                  2             0
#
#             Streaming TV  Streaming Movies  Contract  Paperless Billing  \
# CustomerID
# 3668-QPYBK             0                 0         0                  1
# 9237-HQITU             0                 0         0                  1
# 9305-CDSKC             2                 2         0                  1
# 7892-POOKP             2                 2         0                  1
# 0280-XJGEX             2                 2         0                  1
#
#             Payment Method  Monthly Charges  Total Charges  CLTV
# CustomerID
# 3668-QPYBK               3            53.85         108.15  3239
# 9237-HQITU               2            70.70         151.65  2701
# 9305-CDSKC               2            99.65         820.50  5372
# 7892-POOKP               2           104.80        3046.05  5003
# 0280-XJGEX               0           103.70        5036.30  5340
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Mutual Information

# %%
mi_scores = mutual_info_classif(df_features, target, discrete_features='auto')
mi_scores = pd.Series(mi_scores, index=df_features.columns).sort_values(ascending=False)

plt.figure(figsize=(12, 5))
sns.barplot(x=mi_scores.values, y=mi_scores.index, palette="coolwarm")
plt.title("Importância das Features (Mutual Information)", fontsize=14)
plt.xlabel("MI Score")
plt.ylabel("Features")
plt.show()
# Out:
# <ipython-input-70-55a57f40fa83>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=mi_scores.values, y=mi_scores.index, palette="coolwarm")

# %% [markdown]
# ## Correlation matrix

# %%
plt.figure(figsize = (20,10))
correlation = df_features.corr(method='spearman')  # Spearman é mais robusto para dados categóricos/ordinais
sns.heatmap(correlation, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Heatmap de Correlação - Spearman", fontsize=14)
plt.show()

# %% [markdown]
# Pelo mapa de correlação, percebemos que:
#
# > Latitude e Longitude = -0.86 <br>
# > Tenure Months e Total Charges = 0.89
#
#
# Para evitar a instabilidade dos coeficientes e a dificuldade de interpretação, vamos excluí-las do nosso modelo, evitando assim a multicolinearidade.

# %%
df_features.drop(columns=['Latitude', 'Longitude', 'Total Charges'], inplace=True)

# %%
corr_matrix = df_mi.corr()

# Extract the row corresponding to 'Target_Column'
target_corr = corr_matrix.loc[['Churn Value']]
sorted_columns = target_corr.columns[target_corr.values.argsort()[0]]
target_corr = target_corr[sorted_columns]

# Create the heatmap
plt.figure(figsize=(25, 3))  # Adjust the figure size for a horizontal heatmap
sns.heatmap(target_corr, annot=True, cmap='coolwarm', cbar=False,  vmin=-.6, vmax=1)
plt.title("Correlation with Churn Value")
plt.show()

# %% [markdown]
# ## Train & Test

# %%
# Dividindo os dados em treino e teste
X_train, X_test, y_train, y_test = train_test_split(df_features, target, train_size=0.7, test_size=0.3, random_state=100)

# %%
print(f"X_train: {X_train.shape[0]}")
print(f"X_test: {X_test.shape[0]}")
# Out:
# X_train: 4930
# X_test: 2113

# %% [markdown]
# ## First version of the model

# %%
# Logistic regression model
logm1 = sm.GLM(y_train,(sm.add_constant(X_train)), family = sm.families.Binomial()) # O modelo usado é um Generalized Linear Model
print(logm1.fit().summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            Churn Value   No. Observations:                 4930
# Model:                            GLM   Df Residuals:                     4910
# Model Family:                Binomial   Df Model:                           19
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -1934.5
# Date:                Fri, 07 Mar 2025   Deviance:                       3868.9
# Time:                        23:49:25   Pearson chi2:                 4.76e+03
# No. Iterations:                     6   Pseudo R-squ. (CS):             0.3094
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -1.0109      0.229     -4.407      0.000      -1.461      -0.561
# Gender               -0.0322      0.080     -0.403      0.687      -0.189       0.125
# Senior Citizen        0.0205      0.103      0.199      0.842      -0.182       0.223
# Partner               0.3245      0.092      3.542      0.000       0.145       0.504
# Dependents           -1.7063      0.146    -11.717      0.000      -1.992      -1.421
# Tenure Months        -0.0375      0.003    -12.398      0.000      -0.043      -0.032
# Phone Service        -0.9027      0.175     -5.158      0.000      -1.246      -0.560
# Multiple Lines        0.1174      0.050      2.338      0.019       0.019       0.216
# Internet Service      0.1807      0.078      2.303      0.021       0.027       0.334
# Online Security      -0.2469      0.052     -4.780      0.000      -0.348      -0.146
# Online Backup        -0.0958      0.047     -2.044      0.041      -0.188      -0.004
# Device Protection    -0.0583      0.049     -1.200      0.230      -0.153       0.037
# Tech Support         -0.2696      0.052     -5.162      0.000      -0.372      -0.167
# Streaming TV          0.0528      0.051      1.032      0.302      -0.048       0.153
# Streaming Movies      0.0593      0.051      1.169      0.242      -0.040       0.159
# Contract             -0.7931      0.096     -8.254      0.000      -0.981      -0.605
# Paperless Billing     0.3854      0.091      4.219      0.000       0.206       0.564
# Payment Method        0.0668      0.043      1.546      0.122      -0.018       0.152
# Monthly Charges       0.0262      0.002     11.187      0.000       0.022       0.031
# CLTV               3.679e-05    3.5e-05      1.052      0.293   -3.18e-05       0.000
# =====================================================================================

# %% [markdown]
# Vamos observar `P>|z|`: Ele testa se o coeficiente é estatisticamente significativo.
#
# - Um p-valor menor que 0,05 (ou 0,01) indica que a variável é estatisticamente significativa.
# - Se o p-valor for alto (> 0,05), a variável pode não ter um impacto significativo no churn.

# %% [markdown]
# ## Recursive Feature Elimination (RFE)
#
# Com base no p-value vamos eliminar as variavéis que não são significativas para o modelo.

# %%
logreg = LogisticRegression()

# %%
rfe = RFE(logreg, n_features_to_select=15)           # O RFE vai selecionar as 15 features mais importantes com base no modelo fornecido (logreg)
rfe = rfe.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
print(rfe.support_)  # Mostra quais features foram selecionadas (True/False)
# Out:
# [ True  True  True  True  True  True  True  True  True  True False  True
#   True  True  True  True False False False]

# %%
list(zip(X_train.columns, rfe.support_, rfe.ranking_)) # Mostra a ordem de importância das features (1 é a mais importante)
# Out:
# [('Gender', True, 1),
#  ('Senior Citizen', True, 1),
#  ('Partner', True, 1),
#  ('Dependents', True, 1),
#  ('Tenure Months', True, 1),
#  ('Phone Service', True, 1),
#  ('Multiple Lines', True, 1),
#  ('Internet Service', True, 1),
#  ('Online Security', True, 1),
#  ('Online Backup', True, 1),
#  ('Device Protection', False, 2),
#  ('Tech Support', True, 1),
#  ('Streaming TV', True, 1),
#  ('Streaming Movies', True, 1),
#  ('Contract', True, 1),
#  ('Paperless Billing', True, 1),
#  ('Payment Method', False, 3),
#  ('Monthly Charges', False, 4),
#  ('CLTV', False, 5)]

# %%
# Features/Colunas descartadas pelo RFE
print(X_train.columns[~rfe.support_])
# Out:
# Index(['Device Protection', 'Payment Method', 'Monthly Charges', 'CLTV'], dtype='object')

# %%
# Features mais importantes com o RFE
col = X_train.columns[rfe.support_]
col
# Out:
# Index(['Gender', 'Senior Citizen', 'Partner', 'Dependents', 'Tenure Months',
#        'Phone Service', 'Multiple Lines', 'Internet Service',
#        'Online Security', 'Online Backup', 'Tech Support', 'Streaming TV',
#        'Streaming Movies', 'Contract', 'Paperless Billing'],
#       dtype='object')

# %% [markdown]
# ## Second version of the model

# %%
X_train_sm = sm.add_constant(X_train[col])
logm2 = sm.GLM(y_train,X_train_sm, family = sm.families.Binomial())
res = logm2.fit()
print(res.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            Churn Value   No. Observations:                 4930
# Model:                            GLM   Df Residuals:                     4914
# Model Family:                Binomial   Df Model:                           15
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2000.8
# Date:                Fri, 07 Mar 2025   Deviance:                       4001.7
# Time:                        23:49:25   Pearson chi2:                 4.83e+03
# No. Iterations:                     6   Pseudo R-squ. (CS):             0.2906
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -0.3781      0.157     -2.411      0.016      -0.685      -0.071
# Gender               -0.0475      0.078     -0.607      0.544      -0.201       0.106
# Senior Citizen        0.1540      0.101      1.521      0.128      -0.044       0.352
# Partner               0.3754      0.090      4.176      0.000       0.199       0.552
# Dependents           -1.7736      0.143    -12.367      0.000      -2.055      -1.493
# Tenure Months        -0.0314      0.003    -11.278      0.000      -0.037      -0.026
# Phone Service         0.1968      0.147      1.343      0.179      -0.090       0.484
# Multiple Lines        0.2985      0.047      6.392      0.000       0.207       0.390
# Internet Service     -0.1123      0.068     -1.655      0.098      -0.245       0.021
# Online Security      -0.3143      0.052     -6.006      0.000      -0.417      -0.212
# Online Backup        -0.0833      0.047     -1.774      0.076      -0.175       0.009
# Tech Support         -0.3379      0.053     -6.421      0.000      -0.441      -0.235
# Streaming TV          0.2118      0.049      4.343      0.000       0.116       0.307
# Streaming Movies      0.2068      0.049      4.251      0.000       0.111       0.302
# Contract             -0.9621      0.094    -10.272      0.000      -1.146      -0.779
# Paperless Billing     0.5778      0.088      6.579      0.000       0.406       0.750
# =====================================================================================

# %% [markdown]
# ## Training results

# %%
# fazendo a predição no train set
y_train_pred = res.predict(X_train_sm).values.reshape(-1)
y_train_pred[:10]
# Out:
# array([0.77960404, 0.05693112, 0.03797537, 0.24822615, 0.01491865,
#        0.02312412, 0.21353288, 0.65488148, 0.57875191, 0.00898721])

# %%
result_train = pd.DataFrame({'Churn':y_train.values, 'Churn_Prob':y_train_pred})
result_train['CustomerID'] = y_train.index
result_train['Predicted'] = result_train.Churn_Prob.map(lambda x: 1 if x > 0.5 else 0) # Criando nova coluna 'predicted' com 1 se Churn_Prob > 0.5, caso contrário 0
result_train.head()
# Out:
#    Churn  Churn_Prob  CustomerID  Predicted
# 0      1    0.779604  9124-LHCJQ          1
# 1      0    0.056931  1470-PSXNM          0
# 2      0    0.037975  9128-CPXKI          0
# 3      1    0.248226  2235-ZGKPT          0
# 4      0    0.014919  8510-TMWYB          0

# %%
# Calculando a matriz de confusão
cm_train = metrics.confusion_matrix(result_train.Churn, result_train.Predicted)

plt.figure(figsize=(7,5))
sns.heatmap(cm_train, annot=True, fmt="d", cmap="Blues", xticklabels=["Predicted No", "Predicted Yes"], yticklabels=["Actual No", "Actual Yes"], cbar=False)
plt.title('Confusion Matrix - Training Set', fontsize=14)
plt.show()

# %% [markdown]
# **Classe 0** (negativo): previu corretamente em 3272 casos
#                     previu incorretamente em 564 casos
#
#
# **Classe 1** (positivo): previu corretamente 739 casos
#                     previu incorretamente em 355 casos

# %%
# Acurácia
accuracy = metrics.accuracy_score(result_train['Churn'], result_train['Predicted'])
print(f"Acurácia:{accuracy:.3f}")

# Precisão
precision = metrics.precision_score(result_train['Churn'], result_train['Predicted'])
print(f"Precisão: {precision:.3f}")
# Out:
# Acurácia:0.814
# Precisão: 0.676

# %% [markdown]
# # 🚩 Test results

# %%
# Fazendo a predição no conjunto de teste
X_test_sm = sm.add_constant(X_test[col])
y_test_pred = res.predict(X_test_sm).values.reshape(-1)

# %%
# Criando um DataFrame com os resultados
result_test = pd.DataFrame({'Churn': y_test.values, 'Churn_Prob': y_test_pred})
result_test['CustomerID'] = y_test.index
result_test['Predicted'] = result_test.Churn_Prob.map(lambda x: 1 if x > 0.5 else 0)
result_test
# Out:
#       Churn  Churn_Prob  CustomerID  Predicted
# 0         0    0.484261  8263-OKETD          0
# 1         1    0.152266  7136-RVDTZ          0
# 2         1    0.468468  6413-XKKPU          0
# 3         0    0.671833  3338-CVVEH          1
# 4         0    0.508696  0916-QOFDP          1
# ...     ...         ...         ...        ...
# 2108      1    0.061890  6635-MYYYZ          0
# 2109      0    0.142792  0537-QYZZN          0
# 2110      0    0.003656  5320-BRKGK          0
# 2111      0    0.114649  7874-ECPQJ          0
# 2112      0    0.331564  9314-QDMDW          0
#
# [2113 rows x 4 columns]

# %% [markdown]
# ## Matriz de confusão

# %%
# Calculando a matriz de confusão
cm_test = metrics.confusion_matrix(result_test.Churn, result_test.Predicted)
print(cm_test)
# Out:
# [[1369  178]
#  [ 275  291]]

# %%
# Calculando a matriz de confusão
cm_test = metrics.confusion_matrix(result_test.Churn, result_test.Predicted)

plt.figure(figsize=(7,5))
sns.heatmap(cm_test, annot=True, fmt="d", cmap="Blues", xticklabels=["Predicted No", "Predicted Yes"], yticklabels=["Actual No", "Actual Yes"], cbar=False)
plt.title('Confusion Matrix - Test Set', fontsize=14)
plt.show()

# %% [markdown]
# **Classe 0** (negativo): previu corretamente em 1369 casos
#                     previu incorretamente em 275 casos
#
#
# **Classe 1** (positivo): previu corretamente 291 casos
#                     previu incorretamente em 178 casos

# %% [markdown]
# ## Acurácia e Precisão

# %%
# Acurácia
accuracy = metrics.accuracy_score(result_test['Churn'], result_test['Predicted'])
print(f"Acurácia:{accuracy:.3f}")

# Precisão
precision = metrics.precision_score(result_test['Churn'], result_test['Predicted'])
print(f"Precisão: {precision:.3f}")
# Out:
# Acurácia:0.786
# Precisão: 0.620

# %% [markdown]
# ## Índice AUC

# %%
# Calculando o AUC
auc_score = roc_auc_score(result_test.Churn, result_test.Churn_Prob)
print(f'AUC: {auc_score:.4f}')
# Out:
# AUC: 0.8235

# %% [markdown]
# ## Curva Roc

# %%
# Calculando a curva ROC
fpr, tpr, thresholds = roc_curve(result_test.Churn, result_test.Churn_Prob)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC Curve (AUC = {auc_score:.4f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('Taxa de Falsos Positivos (FPR)')
plt.ylabel('Taxa de Verdadeiros Positivos (TPR)')
plt.title('Curva ROC')
plt.legend(loc='lower right')
plt.show()

# %%
import pickle # Salvando o modelo

with open("logm2.pkl", "wb") as f:
    pickle.dump(res, f)  # 'res' é o modelo ajustado (logm2.fit())
